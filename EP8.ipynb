# %%
import pandas as pd
df=pd.read_csv('Ep8.csv')
print(df)
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer            45      M                3
# 1   818770008  Existing Customer            49      F                5
# 2   713982108  Existing Customer            51      M                3
# 3   769911858  Existing Customer            40      F                4
# 4   709106358  Existing Customer            40      M                3
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer            64      M                1
# 96  772629333  Existing Customer            45      M                3
# 97  720336708  Existing Customer            53      M                3
# 98  802013583  Existing Customer            56      M                3
# 99  711887583  Attrited Customer            47      M                2
#
#    Education_Level Income_Category  Credit_Limit  Total_Revolving_Bal  \
# 0      High School     $60K - $80K       12691.0                  777
# 1         Graduate  Less than $40K        8256.0                  864
# 2         Graduate    $80K - $120K        3418.0                    0
# 3      High School  Less than $40K        3313.0                 2517
# 4       Uneducated     $60K - $80K        4716.0                    0
# ..             ...             ...           ...                  ...
# 95        Graduate  Less than $40K        1709.0                  895
# 96        Graduate     $40K - $60K        3454.0                 1200
# 97       Doctorate     $40K - $60K        3789.0                 1706
# 98         College         $120K +        9689.0                 2250
# 99         Unknown    $80K - $120K        5449.0                 1628
#
#     Avg_Purchase  Total_Trans_Amt
# 0        11914.0             1144
# 1         7392.0             1291
# 2         3418.0             1887
# 3          796.0             1171
# 4         4716.0              816
# ..           ...              ...
# 95         814.0             1673
# 96        2254.0             1313
# 97        2083.0             1609
# 98        7439.0             1158
# 99        3821.0              836
#
# [100 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[5,5])
ax=fig.add_axes([0,0,1,1])
ax.scatter(df['Credit_Limit'],df['Avg_Purchase'])
ax.set_title('credit limit vs Avg Purchase',fontsize=16)
ax.set_xlabel('credit limit',fontsize=12)
ax.set_ylabel('Avg Purchase', fontsize=10)
fig.show()
# Out:
# C:\Users\25 KLE 28\AppData\Local\Temp\ipykernel_25876\3084276963.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import matplotlib.pyplot as plt

df_list = [df['Credit_Limit'], df['Avg_Purchase']]

fig = plt.figure(figsize=[6, 5])
ax = fig.add_axes([0, 0, 1, 1])

ax.set_title('Credit_Limit and Avg_Purchase')

ax.boxplot(df_list, widths=0.5)
ax.set_xticklabels(['Credit_Limit', 'Avg_Purchase'])

plt.show()

# %%
grouped_df=df.groupby('Income_Category').size().reset_index(name='count')
fig=plt.Figure(figsize=[7,5])
ax=fig.add_axes([0,0,1,1])
ax.set_title('no of clusters by income category',fontsize=16)
ax.set_xlabel('income category',fontsize=12)
ax.set_ylabel('count',fontsize=12)
ax.bar(grouped_df['Income_Category'],grouped_df['count'])
plt.tight_layout()
plt.show()

# %%
grouped_df = df.groupby('Income_Category').size().reset_index(name='count')

fig = plt.figure(figsize=[7, 5])
ax = fig.add_axes([0, 0, 1, 1])

ax.set_title('No. of Customers by Income Category', fontsize=16)
ax.set_xlabel('Income Category', fontsize=12)
ax.set_ylabel('Count', fontsize=12)

ax.bar(grouped_df['Income_Category'], grouped_df['count'])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\25 KLE 28\AppData\Local\Temp\ipykernel_25876\3358096820.py:12: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
fig = plt.figure(figsize=[8.6, 6])
ax = fig.add_axes([0, 0, 1, 1])

ax.hist(df['Total_Trans_Amt'], bins=20, edgecolor='black')

ax.set_title('Distribution of Total Transaction Amount', fontsize=17)
ax.set_xlabel('Total Transaction Amount', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)

plt.show()

# %%
pie_df=pd.DataFrame()
pie_df['count']=df['Attrition_Flag'].value_counts()
pie_df=pie_df.reset_index()
pie_df.rename(columns={'index':'customers'},inplace=True)
pie_df
# Out:
#       Attrition_Flag  count
# 0  Existing Customer     93
# 1  Attrited Customer      7

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))

plt.title('Attrition Flag')
plt.pie(
    pie_df['count'],
    labels=pie_df['Attrition_Flag'],
    autopct='%0.1f%%'
)

plt.show()
