# %%
import pandas as pd

# %%
df=pd.read_csv('Book1.csv')

# %%
print(df)
# Out:
#   First_name Last_name
# 0     puneet         k
# 1     satvik        jk
# 2     madesh         h
# 3     sachin         h
