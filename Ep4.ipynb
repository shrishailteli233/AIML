# %%
import pandas as pd

# %%
df=pd.read_csv('Book1.csv')

# %%
print(df)
# Out:
#   First_name Last_name                type     Department  yoe  salary
# 0     puneet         m           full_time  adimistration    1    5000
# 1     satvik        jk              intern       techical    2   10000
# 2     madesh         a           full_time  adimistration    5   50000
# 3     sachin         h  part_time empolyee       techical    7   55000
# 4      shree         t  full_time employee     management    6    7000

# %%
print(df1)
# Out:
# yoe                      1        2        5       6        7
# type
# full_time           5000.0      NaN  50000.0     NaN      NaN
# full_time employee     NaN      NaN      NaN  7000.0      NaN
# intern                 NaN  10000.0      NaN     NaN      NaN
# part_time empolyee     NaN      NaN      NaN     NaN  55000.0

# %%
df1=df.pivot_table(index='type',columns='Department',values='salary')
print(df1)
# Out:
# Department          adimistration  management  techical
# type
# full_time                 27500.0         NaN       NaN
# full_time employee            NaN      7000.0       NaN
# intern                        NaN         NaN   10000.0
# part_time empolyee            NaN         NaN   55000.0

# %%
df1=df.pivot_table(index='type',columns='Department',values='salary')

# %%
print(df1)
# Out:
# Department          adimistration  management  techical
# type
# full_time                 27500.0         NaN       NaN
# full_time employee            NaN      7000.0       NaN
# intern                        NaN         NaN   10000.0
# part_time empolyee            NaN         NaN   55000.0

# %%
df1=df.pivot_table(index='type',columns='Department',values='salary',aggfunc='mean')

# %%
print(df1)
# Out:
# Department          adimistration  management  techical
# type
# full_time                 27500.0         NaN       NaN
# full_time employee            NaN      7000.0       NaN
# intern                        NaN         NaN   10000.0
# part_time empolyee            NaN         NaN   55000.0

# %%
df2=df.pivot_table(index='type',columns='Department',values='salary')

# %%
print(df2)
# Out:
# Department          adimistration  management  techical
# type
# full_time                 27500.0         NaN       NaN
# full_time employee            NaN      7000.0       NaN
# intern                        NaN         NaN   10000.0
# part_time empolyee            NaN         NaN   55000.0

# %%
df1=df.pivot_table(index='type',columns='Department',values='salary',aggfunc=['mean','sum','count'])

# %%
print(df1)
# Out:
#                             mean                               sum             \
# Department         adimistration management techical adimistration management
# type
# full_time                27500.0        NaN      NaN       55000.0        NaN
# full_time employee           NaN     7000.0      NaN           NaN     7000.0
# intern                       NaN        NaN  10000.0           NaN        NaN
# part_time empolyee           NaN        NaN  55000.0           NaN        NaN
#
#                                     count
# Department         techical adimistration management techical
# type
# full_time               NaN           2.0        NaN      NaN
# full_time employee      NaN           NaN        1.0      NaN
# intern              10000.0           NaN        NaN      1.0
# part_time empolyee  55000.0           NaN        NaN      1.0

# %%
df1=df.pivot_table(index='type',columns='Department',values='salary',aggfunc='std')

# %%
print(df1)
# Out:
# Department  adimistration
# type
# full_time    31819.805153
