# %%
import numpy as np

# %%
demo1=np.array([1,2,3,4,5])
demo2=np.array([4,3,2,1,5])
res_map=np.array(list(map(lambda x,y:x+y,demo1,demo2)))

# %%
print("result of map using numpy",res_map)
# Out:
# result of map using numpy [ 5  5  5  5 10]

# %%
import numpy as np

# %%
from functools import reduce
demo1=np.array([1,2,3,4,5])
demo2=np.array([4,3,2,1,5])
res_reduce=reduce(lambda x,y:x+y,demo2)
print("res_reduce of map using numpy",res_reduce)
# Out:
# res_reduce of map using numpy 15

# %%
import numpy as np

# %%
demo1=np.array([1,2,3,4,5])
demo2=np.array([4,3,2,1,5])
def square(x):
    return x**2
vect_square=np.vectorize(square)
apply_square=vect_square(demo1)
print(apply_square)
# Out:
# [ 1  4  9 16 25]

# %%
import pandas as pd

# %%
data={'A':[420,380,390],'B':[50,40,45]}
df=pd.DataFrame(data)
df['A_mapped']=df['A'].map(lambda x:x+2)
print("mapped values",df['A_mapped'])
# Out:
# mapped values 0    422
# 1    382
# 2    392
# Name: A_mapped, dtype: int64

# %%
import pandas as pd

# %%
data={'A':[420,380,390],'B':[50,40,45]}
df=pd.DataFrame(data)
print(df)
df['sum']=df.apply(lambda row:row['A']+row['B'],axis=1)
print("sum of A & B using apply:",df['sum'])
# Out:
#      A   B
# 0  420  50
# 1  380  40
# 2  390  45
# sum of A & B using apply: 0    470
# 1    420
# 2    435
# Name: sum, dtype: int64

# %%
import pandas as pd

# %%
from functools import reduce
data={'A':[420,380,390],'B':[50,40,45]}
df=pd.DataFrame(data)
print(df)
res_reduce=reduce(lambda x,y:x+y,df['B'])
print("res_reduce")
# Out:
#      A   B
# 0  420  50
# 1  380  40
# 2  390  45
# res_reduce
