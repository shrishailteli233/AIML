# %%
import numpy as np

# %%
step_data = np.array([
    [1, 4335],
    [2, 9552],
    [3, 7332],
    [4, 4504],
    [5, 5335],
    [6, 7552],
    [7, 8332],
    [8, 6504],
    [9, 8965],
    [10, 7689]
])

# %%
print(step_data)
# Out:
# [[   1 4335]
#  [   2 9552]
#  [   3 7332]
#  [   4 4504]
#  [   5 5335]
#  [   6 7552]
#  [   7 8332]
#  [   8 6504]
#  [   9 8965]
#  [  10 7689]]

# %%
step_data[:,1]+=1000

# %%
step_data[:,1]>7000
# Out:
# array([False,  True,  True, False, False,  True,  True,  True,  True,
#         True])

# %%
np.sort(step_data[:,1])
# Out:
# array([ 5335,  5504,  6335,  7504,  8332,  8552,  8689,  9332,  9965,
#        10552])
